# %% [markdown]
# # Week 1-2 - Class Practice
# ## Data Wrangling in Python
# ### Zeehasham Rasheed
# Hands on Practice

# %%
import pandas as pd

# %%
data = pd.read_csv('NeedsWrangling.csv')

# %%
data
# Out:
#     CustomerID  Firstname  Lastname          Address      City State    Zip  \
# 0            1      Billy     Davis      121 Main St  Prescott    AZ  86305
# 1            2      Betty     Davis  121 Main Street  Prescott    AZ  86305
# 2            3    William  Franklin    120 Miller St  Prescott    AZ  86303
# 3            4       John     Smith     3331 Main St  prescott    az  86302
# 4            5      Besty    Watson         121 Main  Prescott    Az  86305
# 5            6      Louis     Davis     121 Main Str  Prescott    az   8601
# 6            7      Oscar     Swane      333 Main St  Prescott    AZ  86302
# 7            8      Allen    Lawson     555 Penelope  Prescott    AZ  86305
# 8            1      Billy     Davis      121 Main St  Prescott    AZ  86305
# 9            6      Louis     Davis     121 Main Str  Prescott    az   8601
# 10          11     Laurie   Wallace         1 Gatsby  Prescott    AZ  86305
# 11          12    William    Frank      5 West Smith  Prescutt    AZ  86305
#
#           Email
# 0    Bd@dma.net
# 1   db2@dma.net
# 2    wf@dma.net
# 3    js@dma.net
# 4    bw@dma.net
# 5    ld@dma.net
# 6    os@dma.net
# 7    al@dma.net
# 8    Bd@dma.net
# 9    ld@dma.net
# 10   lw@dma.net
# 11   wf@dma.net

# %%
data.head()
# Out:
#    CustomerID Firstname  Lastname          Address      City State    Zip  \
# 0           1     Billy     Davis      121 Main St  Prescott    AZ  86305
# 1           2     Betty     Davis  121 Main Street  Prescott    AZ  86305
# 2           3   William  Franklin    120 Miller St  Prescott    AZ  86303
# 3           4      John     Smith     3331 Main St  prescott    az  86302
# 4           5     Besty    Watson         121 Main  Prescott    Az  86305
#
#          Email
# 0   Bd@dma.net
# 1  db2@dma.net
# 2   wf@dma.net
# 3   js@dma.net
# 4   bw@dma.net

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# dtype: bool

# %%
data2 = data.drop_duplicates('CustomerID')

# %%
data2
# Out:
#     CustomerID  Firstname  Lastname          Address      City State    Zip  \
# 0            1      Billy     Davis      121 Main St  Prescott    AZ  86305
# 1            2      Betty     Davis  121 Main Street  Prescott    AZ  86305
# 2            3    William  Franklin    120 Miller St  Prescott    AZ  86303
# 3            4       John     Smith     3331 Main St  prescott    az  86302
# 4            5      Besty    Watson         121 Main  Prescott    Az  86305
# 5            6      Louis     Davis     121 Main Str  Prescott    az   8601
# 6            7      Oscar     Swane      333 Main St  Prescott    AZ  86302
# 7            8      Allen    Lawson     555 Penelope  Prescott    AZ  86305
# 10          11     Laurie   Wallace         1 Gatsby  Prescott    AZ  86305
# 11          12    William    Frank      5 West Smith  Prescutt    AZ  86305
#
#           Email
# 0    Bd@dma.net
# 1   db2@dma.net
# 2    wf@dma.net
# 3    js@dma.net
# 4    bw@dma.net
# 5    ld@dma.net
# 6    os@dma.net
# 7    al@dma.net
# 10   lw@dma.net
# 11   wf@dma.net

# %% [markdown]
# How to access any column

# %%
data2['Firstname']
# Out:
# 0         Billy
# 1         Betty
# 2       William
# 3          John
# 4         Besty
# 5         Louis
# 6         Oscar
# 7         Allen
# 10       Laurie
# 11      William
# Name: Firstname, dtype: object

# %%
pd.set_option('mode.chained_assignment',  None)

# %% [markdown]
# Creating a new column and assign values to it

# %%
data2['Length'] = data2['Firstname'].map(len)

# %%
data2
# Out:
#     CustomerID  Firstname  Lastname          Address      City State    Zip  \
# 0            1      Billy     Davis      121 Main St  Prescott    AZ  86305
# 1            2      Betty     Davis  121 Main Street  Prescott    AZ  86305
# 2            3    William  Franklin    120 Miller St  Prescott    AZ  86303
# 3            4       John     Smith     3331 Main St  prescott    az  86302
# 4            5      Besty    Watson         121 Main  Prescott    Az  86305
# 5            6      Louis     Davis     121 Main Str  Prescott    az   8601
# 6            7      Oscar     Swane      333 Main St  Prescott    AZ  86302
# 7            8      Allen    Lawson     555 Penelope  Prescott    AZ  86305
# 10          11     Laurie   Wallace         1 Gatsby  Prescott    AZ  86305
# 11          12    William    Frank      5 West Smith  Prescutt    AZ  86305
#
#           Email  Length
# 0    Bd@dma.net       5
# 1   db2@dma.net       5
# 2    wf@dma.net       7
# 3    js@dma.net       4
# 4    bw@dma.net       5
# 5    ld@dma.net       5
# 6    os@dma.net       5
# 7    al@dma.net       5
# 10   lw@dma.net       6
# 11   wf@dma.net       9

# %%
data2['Firstname'][2]
# Out:
# 'William'

# %%
len(data2['Firstname'][2])
# Out:
# 7

# %%
data2['Firstname'][11]
# Out:
# '  William'

# %%
len(data2['Firstname'][11])
# Out:
# 9

# %%
# data2['Firstname'] = data2['Firstname'].map(str.strip)
### OR
# data2.loc[:,'Firstname'] = data2['Firstname'].str.strip()
### OR
data2['Firstname'] = data2['Firstname'].str.strip()

# %%
data2['Firstname'][2]
# Out:
# 'William'

# %%
data2['Firstname'][11]
# Out:
# 'William'

# %%
data2
# Out:
#     CustomerID Firstname  Lastname          Address      City State    Zip  \
# 0            1     Billy     Davis      121 Main St  Prescott    AZ  86305
# 1            2     Betty     Davis  121 Main Street  Prescott    AZ  86305
# 2            3   William  Franklin    120 Miller St  Prescott    AZ  86303
# 3            4      John     Smith     3331 Main St  prescott    az  86302
# 4            5     Besty    Watson         121 Main  Prescott    Az  86305
# 5            6     Louis     Davis     121 Main Str  Prescott    az   8601
# 6            7     Oscar     Swane      333 Main St  Prescott    AZ  86302
# 7            8     Allen    Lawson     555 Penelope  Prescott    AZ  86305
# 10          11    Laurie   Wallace         1 Gatsby  Prescott    AZ  86305
# 11          12   William    Frank      5 West Smith  Prescutt    AZ  86305
#
#           Email  Length
# 0    Bd@dma.net       5
# 1   db2@dma.net       5
# 2    wf@dma.net       7
# 3    js@dma.net       4
# 4    bw@dma.net       5
# 5    ld@dma.net       5
# 6    os@dma.net       5
# 7    al@dma.net       5
# 10   lw@dma.net       6
# 11   wf@dma.net       9

# %%
data2['Length'] = data2['Firstname'].map(len)

# %%
data2
# Out:
#     CustomerID Firstname  Lastname          Address      City State    Zip  \
# 0            1     Billy     Davis      121 Main St  Prescott    AZ  86305
# 1            2     Betty     Davis  121 Main Street  Prescott    AZ  86305
# 2            3   William  Franklin    120 Miller St  Prescott    AZ  86303
# 3            4      John     Smith     3331 Main St  prescott    az  86302
# 4            5     Besty    Watson         121 Main  Prescott    Az  86305
# 5            6     Louis     Davis     121 Main Str  Prescott    az   8601
# 6            7     Oscar     Swane      333 Main St  Prescott    AZ  86302
# 7            8     Allen    Lawson     555 Penelope  Prescott    AZ  86305
# 10          11    Laurie   Wallace         1 Gatsby  Prescott    AZ  86305
# 11          12   William    Frank      5 West Smith  Prescutt    AZ  86305
#
#           Email  Length
# 0    Bd@dma.net       5
# 1   db2@dma.net       5
# 2    wf@dma.net       7
# 3    js@dma.net       4
# 4    bw@dma.net       5
# 5    ld@dma.net       5
# 6    os@dma.net       5
# 7    al@dma.net       5
# 10   lw@dma.net       6
# 11   wf@dma.net       7

# %%
data2['State'] = data2['State'].str.upper()
# data2.loc[:,'State'] = data2['State'].str.upper()

# %%
data2
# Out:
#     CustomerID Firstname  Lastname          Address      City State    Zip  \
# 0            1     Billy     Davis      121 Main St  Prescott    AZ  86305
# 1            2     Betty     Davis  121 Main Street  Prescott    AZ  86305
# 2            3   William  Franklin    120 Miller St  Prescott    AZ  86303
# 3            4      John     Smith     3331 Main St  prescott    AZ  86302
# 4            5     Besty    Watson         121 Main  Prescott    AZ  86305
# 5            6     Louis     Davis     121 Main Str  Prescott    AZ   8601
# 6            7     Oscar     Swane      333 Main St  Prescott    AZ  86302
# 7            8     Allen    Lawson     555 Penelope  Prescott    AZ  86305
# 10          11    Laurie   Wallace         1 Gatsby  Prescott    AZ  86305
# 11          12   William    Frank      5 West Smith  Prescutt    AZ  86305
#
#           Email  Length
# 0    Bd@dma.net       5
# 1   db2@dma.net       5
# 2    wf@dma.net       7
# 3    js@dma.net       4
# 4    bw@dma.net       5
# 5    ld@dma.net       5
# 6    os@dma.net       5
# 7    al@dma.net       5
# 10   lw@dma.net       6
# 11   wf@dma.net       7

# %%
data2['Address'].str.contains('121 Main St')
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 10    False
# 11    False
# Name: Address, dtype: bool

# %%
idx = data2['Address'].str.contains('121 Main St')

# %%
idx
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 10    False
# 11    False
# Name: Address, dtype: bool

# %%
data2.loc[idx,'Address'] = '121 Main St'

# %%
data2
# Out:
#     CustomerID Firstname  Lastname          Address      City State    Zip  \
# 0            1     Billy     Davis      121 Main St  Prescott    AZ  86305
# 1            2     Betty     Davis      121 Main St  Prescott    AZ  86305
# 2            3   William  Franklin    120 Miller St  Prescott    AZ  86303
# 3            4      John     Smith     3331 Main St  prescott    AZ  86302
# 4            5     Besty    Watson         121 Main  Prescott    AZ  86305
# 5            6     Louis     Davis      121 Main St  Prescott    AZ   8601
# 6            7     Oscar     Swane      333 Main St  Prescott    AZ  86302
# 7            8     Allen    Lawson     555 Penelope  Prescott    AZ  86305
# 10          11    Laurie   Wallace         1 Gatsby  Prescott    AZ  86305
# 11          12   William    Frank      5 West Smith  Prescutt    AZ  86305
#
#           Email  Length
# 0    Bd@dma.net       5
# 1   db2@dma.net       5
# 2    wf@dma.net       7
# 3    js@dma.net       4
# 4    bw@dma.net       5
# 5    ld@dma.net       5
# 6    os@dma.net       5
# 7    al@dma.net       5
# 10   lw@dma.net       6
# 11   wf@dma.net       7

# %%
data2['Address'].value_counts()
# Out:
# 121 Main St        3
# 120 Miller St      1
# 3331 Main St       1
# 121 Main           1
# 333 Main St        1
# 555 Penelope       1
# 1 Gatsby           1
#    5 West Smith    1
# Name: Address, dtype: int64

# %%
data3 = pd.read_csv('NeedsWranglingJoin.csv')

# %%
data3
# Out:
#     CustomerID  Gender
# 0            1    Male
# 1            3    Male
# 2            4    Male
# 3            6    Male
# 4            7    Male
# 5            8    Male
# 6            1    Male
# 7            6    Male
# 8           12    Male
# 9            2  Female
# 10           5  Female
# 11          11  Female

# %%
data3.head()
# Out:
#    CustomerID Gender
# 0           1   Male
# 1           3   Male
# 2           4   Male
# 3           6   Male
# 4           7   Male

# %% [markdown]
# Merging or Joining two dataframe using common column

# %%
join_data = pd.merge(data2,data3,on='CustomerID')
#join_data = pd.merge(data3,data2,on='CustomerID')

# %%
join_data
# Out:
#     CustomerID  Firstname  Lastname          Address      City State    Zip  \
# 0            1      Billy     Davis      121 Main St  Prescott    AZ  86305
# 1            1      Billy     Davis      121 Main St  Prescott    AZ  86305
# 2            2      Betty     Davis  121 Main Street  Prescott    AZ  86305
# 3            3    William  Franklin    120 Miller St  Prescott    AZ  86303
# 4            4       John     Smith     3331 Main St  prescott    az  86302
# 5            5      Besty    Watson         121 Main  Prescott    Az  86305
# 6            6      Louis     Davis     121 Main Str  Prescott    az   8601
# 7            6      Louis     Davis     121 Main Str  Prescott    az   8601
# 8            7      Oscar     Swane      333 Main St  Prescott    AZ  86302
# 9            8      Allen    Lawson     555 Penelope  Prescott    AZ  86305
# 10          11     Laurie   Wallace         1 Gatsby  Prescott    AZ  86305
# 11          12    William    Frank      5 West Smith  Prescutt    AZ  86305
#
#           Email  Gender
# 0    Bd@dma.net    Male
# 1    Bd@dma.net    Male
# 2   db2@dma.net  Female
# 3    wf@dma.net    Male
# 4    js@dma.net    Male
# 5    bw@dma.net  Female
# 6    ld@dma.net    Male
# 7    ld@dma.net    Male
# 8    os@dma.net    Male
# 9    al@dma.net    Male
# 10   lw@dma.net  Female
# 11   wf@dma.net    Male

# %% [markdown]
# # Assignment Data File

# %%
import pandas as pd

# %%
df = pd.read_csv('580SurveyCleanup2.csv')

# %%
df.head()
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2          Unnamed: 3   Unnamed: 4  \
# 0        No.             Time     Status  Duration (Seconds)  Access Code
# 1          1  10/3/2023 17:49  Completed               11646          NaN
# 2          2  10/3/2023 17:49  Completed                 113          NaN
# 3          3  10/3/2023 17:49  Completed                 572          NaN
# 4          4  10/3/2023 17:50  Completed                 365          NaN
#
#       Unnamed: 5      Unnamed: 6     Unnamed: 7 Unnamed: 8  \
# 0  Email Address      IP Address        Country     Region
# 1            NaN  100.36.167.226  United States   Virginia
# 2            NaN   98.169.26.134  United States   Virginia
# 3            NaN    98.169.52.23  United States   Virginia
# 4            NaN  69.255.182.253  United States   Virginia
#
#                Unnamed: 9  ...             Q12.1         Q12.2  \
# 0  City / Town / District  ...  Some familiarity  Average user
# 1                 Fairfax  ...                 1           NaN
# 2                 Fairfax  ...               NaN           NaN
# 3          Greenway Downs  ...               NaN             1
# 4             Gainesville  ...                 1           NaN
#
#                        Q12.3          Q12.4  Q13 Q13.1  Q14 Q14.1     Q14.2  \
# 0  Frequent use for projects  Fluent/expert  Yes    No  Yes    No  Not sure
# 1                        NaN            NaN    1   NaN    1   NaN       NaN
# 2                        NaN            NaN    1   NaN  NaN     1       NaN
# 3                        NaN            NaN  NaN     1  NaN   NaN         1
# 4                        NaN            NaN  NaN     1    1   NaN       NaN
#
#                                                Q13.2
# 0  What is your goal for learning about data anal...
# 1                                                NaN
# 2                                                NaN
# 3  As part of my work, I have access to a lot of ...
# 4                                                NaN
#
# [5 rows x 51 columns]

# %% [markdown]
# Separating columns of students profile information

# %%
df_1 = df.iloc[:,1:12]

# %%
df_1.head()
# Out:
#         Unnamed: 1 Unnamed: 2          Unnamed: 3   Unnamed: 4     Unnamed: 5  \
# 0             Time     Status  Duration (Seconds)  Access Code  Email Address
# 1  10/3/2023 17:49  Completed               11646          NaN            NaN
# 2  10/3/2023 17:49  Completed                 113          NaN            NaN
# 3  10/3/2023 17:49  Completed                 572          NaN            NaN
# 4  10/3/2023 17:50  Completed                 365          NaN            NaN
#
#        Unnamed: 6     Unnamed: 7 Unnamed: 8              Unnamed: 9  \
# 0      IP Address        Country     Region  City / Town / District
# 1  100.36.167.226  United States   Virginia                 Fairfax
# 2   98.169.26.134  United States   Virginia                 Fairfax
# 3    98.169.52.23  United States   Virginia          Greenway Downs
# 4  69.255.182.253  United States   Virginia             Gainesville
#
#   Unnamed: 10 Unnamed: 11
# 0    Latitude   Longitude
# 1    -77.2891     38.8209
# 2     -77.263     38.8605
# 3    -77.2331     38.9645
# 4    -77.6308     38.8175

# %% [markdown]
# ### Replacing header with first row

# %%
df_1.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='object')

# %%
df_1.columns = df_1.iloc[0]
df_1 = df_1[1:]

# %%
df_1.head()
# Out:
# 0             Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
# 0      IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
# 0 Longitude
# 1   38.8209
# 2   38.8605
# 3   38.9645
# 4   38.8175
# 5    37.751

# %% [markdown]
# ### Getting Question 1 coulumns

# %%
df2 = df.iloc[:,[12,13]]

# %%
df2.head()
# Out:
#     Q1  Q1.1
# 0  2.0   4.0
# 1  NaN   1.0
# 2  1.0   NaN
# 3  1.0   NaN
# 4  1.0   NaN

# %% [markdown]
# ### Replacing header with first row

# %%
df2.columns = df2.iloc[0].astype(str)
df2 = df2[1:]

# %%
df2.head()
# Out:
# 0  2.0  4.0
# 1  NaN  1.0
# 2  1.0  NaN
# 3  1.0  NaN
# 4  1.0  NaN
# 5  1.0  NaN

# %% [markdown]
# ### Replace every "1" value with its respective column name

# %%
df3 = df2.loc[:, '2.0':'4.0'].replace(1, pd.Series(df2.columns, df2.columns)).fillna('')

# %%
df3
# Out:
# 0   2.0  4.0
# 1        4.0
# 2   2.0
# 3   2.0
# 4   2.0
# 5   2.0
# 6   2.0
# 7   2.0
# 8   2.0
# 9   2.0
# 10       4.0
# 11  2.0
# 12       4.0
# 13  2.0
# 14  2.0
# 15       4.0
# 16       4.0
# 17  2.0
# 18  2.0
# 19       4.0
# 20       4.0
# 21       4.0
# 22  2.0
# 23       4.0
# 24       4.0
# 25       4.0
# 26  2.0
# 27  2.0
# 28       4.0
# 29       4.0
# 30  2.0
# 31       4.0
# 32  2.0
# 33  2.0
# 34       4.0
# 35  2.0
# 36       4.0

# %% [markdown]
# ### concatenate Q1 columns into one final column

# %%
df4 = pd.DataFrame(df3.iloc[:,0] + df3.iloc[:,1])

# %%
df4
# Out:
#       0
# 1   4.0
# 2   2.0
# 3   2.0
# 4   2.0
# 5   2.0
# 6   2.0
# 7   2.0
# 8   2.0
# 9   2.0
# 10  4.0
# 11  2.0
# 12  4.0
# 13  2.0
# 14  2.0
# 15  4.0
# 16  4.0
# 17  2.0
# 18  2.0
# 19  4.0
# 20  4.0
# 21  4.0
# 22  2.0
# 23  4.0
# 24  4.0
# 25  4.0
# 26  2.0
# 27  2.0
# 28  4.0
# 29  4.0
# 30  2.0
# 31  4.0
# 32  2.0
# 33  2.0
# 34  4.0
# 35  2.0
# 36  4.0

# %%
df4.columns = ['Q1']

# %%
df4.head()
# Out:
#     Q1
# 1  4.0
# 2  2.0
# 3  2.0
# 4  2.0
# 5  2.0

# %%
df5 = pd.concat([df_1,df4],axis=1)

# %%
df5.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/2023 17:49  Completed              11646         NaN           NaN
# 2  10/3/2023 17:49  Completed                113         NaN           NaN
# 3  10/3/2023 17:49  Completed                572         NaN           NaN
# 4  10/3/2023 17:50  Completed                365         NaN           NaN
# 5  10/3/2023 17:51  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
#   Longitude   Q1
# 1   38.8209  4.0
# 2   38.8605  2.0
# 3   38.9645  2.0
# 4   38.8175  2.0
# 5    37.751  2.0

# %%
df5
# Out:
#                Time      Status Duration (Seconds) Access Code Email Address  \
# 1   10/3/2023 17:49   Completed              11646         NaN           NaN
# 2   10/3/2023 17:49   Completed                113         NaN           NaN
# 3   10/3/2023 17:49   Completed                572         NaN           NaN
# 4   10/3/2023 17:50   Completed                365         NaN           NaN
# 5   10/3/2023 17:51   Completed                 92         NaN           NaN
# 6   10/3/2023 17:59  Incomplete                221         NaN           NaN
# 7   10/3/2023 18:23   Completed             115983         NaN           NaN
# 8   10/3/2023 19:10  Incomplete                 40         NaN           NaN
# 9   10/3/2023 19:25   Completed                137         NaN           NaN
# 10  10/3/2023 19:56  Incomplete                179         NaN           NaN
# 11  10/3/2023 20:14   Completed                127         NaN           NaN
# 12  10/3/2023 21:38   Completed                269         NaN           NaN
# 13  10/3/2023 21:41   Completed                117         NaN           NaN
# 14  10/3/2023 22:49   Completed               5966         NaN           NaN
# 15  10/3/2023 23:25   Completed                254         NaN           NaN
# 16   10/4/2023 0:28   Completed                526         NaN           NaN
# 17   10/4/2023 5:22   Completed                398         NaN           NaN
# 18   10/4/2023 5:36   Completed             128253         NaN           NaN
# 19   10/4/2023 5:47   Completed                239         NaN           NaN
# 20  10/4/2023 10:32   Completed                255         NaN           NaN
# 21  10/4/2023 11:03   Completed                256         NaN           NaN
# 22  10/4/2023 12:34   Completed                674         NaN           NaN
# 23  10/4/2023 13:36   Completed                130         NaN           NaN
# 24  10/4/2023 13:50   Completed                275         NaN           NaN
# 25  10/4/2023 21:28   Completed                325         NaN           NaN
# 26   10/5/2023 9:37   Completed                257         NaN           NaN
# 27   10/5/2023 9:36   Completed                657         NaN           NaN
# 28  10/5/2023 10:36   Completed               1750         NaN           NaN
# 29  10/5/2023 11:02   Completed                887         NaN           NaN
# 30  10/5/2023 11:17   Completed                180         NaN           NaN
# 31  10/5/2023 12:52   Completed                392         NaN           NaN
# 32  10/5/2023 12:56  Incomplete                192         NaN           NaN
# 33  10/5/2023 13:52   Completed                277         NaN           NaN
# 34  10/5/2023 15:34   Completed                119         NaN           NaN
# 35  10/5/2023 15:41   Completed                149         NaN           NaN
# 36  10/5/2023 17:58   Completed                285         NaN           NaN
#
#          IP Address        Country    Region City / Town / District  Latitude  \
# 1    100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2     98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3      98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4    69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5    138.88.108.230  United States       NaN                    NaN   -97.822
# 6     108.56.134.80  United States  Virginia                 Reston  -77.3489
# 7    108.48.175.220  United States  Virginia              Arlington  -77.0987
# 8     173.67.199.85  United States  Virginia                Ashburn   -77.539
# 9      74.96.114.12  United States  Virginia             Woodbridge  -77.3197
# 10    107.77.241.32  United States     Texas                    NaN  -96.8217
# 11   138.88.182.245  United States  Maryland            Takoma Park   -77.004
# 12     72.83.246.60  United States  Virginia                Fairfax   -77.263
# 13    96.241.43.105  United States  Virginia              Chantilly  -77.4512
# 14    71.191.72.223  United States  Virginia                  Burke  -77.2866
# 15    73.134.53.227  United States  Maryland            Hyattsville  -76.8696
# 16     73.86.219.52  United States  Maryland              Baltimore  -76.6355
# 17   69.138.215.127  United States  Virginia              Arlington   -77.113
# 18    72.196.231.70  United States  Virginia            Springfield  -77.2333
# 19     100.15.54.17  United States  Virginia             Woodbridge  -77.3197
# 20   184.170.83.239  United States  Virginia               Rustburg  -79.0985
# 21   100.36.243.102  United States  Virginia                Fairfax  -77.3375
# 22    108.56.134.80  United States  Virginia                 Reston  -77.3489
# 23    73.163.163.82  United States  Maryland              Baltimore   -76.557
# 24    138.88.223.87  United States       NaN                    NaN   -97.822
# 25    100.36.50.114  United States       NaN                    NaN   -97.822
# 26    108.51.59.195  United States  Virginia                  Burke  -77.2866
# 27    72.83.246.219  United States  Virginia                Fairfax   -77.263
# 28   100.36.118.186  United States  Virginia                  Burke  -77.2866
# 29    172.58.187.98  United States  Maryland              Baltimore  -76.6949
# 30   72.196.230.201  United States  Virginia            Springfield  -77.2333
# 31   108.18.111.204  United States  Virginia                 Lorton   -77.206
# 32    71.191.72.223  United States  Virginia                  Burke  -77.2866
# 33     184.191.72.8  United States  Virginia           Falls Church  -77.1425
# 34  141.156.160.243  United States       NaN                    NaN   -97.822
# 35    71.206.51.121  United States  Maryland              Frederick  -77.2758
# 36  129.174.252.234  United States  Virginia                Fairfax  -77.3375
#
#    Longitude   Q1
# 1    38.8209  4.0
# 2    38.8605  2.0
# 3    38.9645  2.0
# 4    38.8175  2.0
# 5     37.751  2.0
# 6    38.9311  2.0
# 7      38.86  2.0
# 8     39.018  2.0
# 9     38.678  2.0
# 10   32.7787  4.0
# 11   38.9827  2.0
# 12   38.8605  4.0
# 13   38.9036  2.0
# 14   38.7851  2.0
# 15   38.9544  4.0
# 16   39.3555  4.0
# 17   38.8747  2.0
# 18   38.7438  2.0
# 19    38.678  4.0
# 20   37.2544  4.0
# 21   38.8357  4.0
# 22   38.9311  2.0
# 23   39.2784  4.0
# 24    37.751  4.0
# 25    37.751  4.0
# 26   38.7851  2.0
# 27   38.8605  2.0
# 28   38.7851  4.0
# 29    39.282  4.0
# 30   38.7438  2.0
# 31   38.6911  4.0
# 32   38.7851  2.0
# 33   38.8472  2.0
# 34    37.751  4.0
# 35   39.4624  2.0
# 36   38.8357  4.0

# %% [markdown]
# ### Checking Null or Nan values

# %%
df5.isnull().sum()
# Out:
# Time                       0
# Status                     0
# Duration (Seconds)         0
# Access Code               36
# Email Address             36
# IP Address                 0
# Country                    0
# Region                     4
# City / Town / District     5
# Latitude                   0
# Longitude                  0
# Q1                         0
# dtype: int64

# %% [markdown]
# ### Count Unique Values in a column

# %%
df5['Q1'].value_counts()
# Out:
# 2.0    20
# 4.0    16
# Name: Q1, dtype: int64

# %% [markdown]
# ### Summary Statistics

# %%
df5.describe()
# Out:
#                    Time     Status Duration (Seconds) Access Code  \
# count                36         36                 36           0
# unique               34          2                 36           0
# top     10/3/2023 17:49  Completed              11646         NaN
# freq                  3         32                  1         NaN
#
#        Email Address     IP Address        Country    Region  \
# count              0             36             36        32
# unique             0             34              1         3
# top              NaN  108.56.134.80  United States  Virginia
# freq             NaN              2             36        25
#
#        City / Town / District  Latitude Longitude   Q1
# count                      31        36        36   36
# unique                     17        24        24    2
# top                   Fairfax  -77.2866   38.7851  2.0
# freq                        6         4         4   20

# %%
df5['Q1'].describe()
# Out:
# count      36
# unique      2
# top       2.0
# freq       20
# Name: Q1, dtype: object
